# %% [markdown]
# # Sheet 2

# %% [markdown]
# Markus Müllenmeister 7321662
#
# Alex   Specht

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### a:

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

executeAllSubExercises= True

N= 10**6
h= 2
xStart=0.5

def w(x):
    return 1/np.sqrt(np.pi)*np.exp(-np.power(x, 2))

def metropolis(x, w, h, xStart):
    x[0]= xStart
    for i in range(1, x.shape[0]):
        xnew= (np.random.rand()*2-1)*h+x[i-1]
        if w(xnew)/w(x[i-1])<np.random.rand():
            x[i]=x[i-1]
        else:
            x[i]= xnew
    return x

def metropolisAccept(x, w, h, xStart):
    x[0]= xStart
    for i in range(1, x.shape[0]):
        ann= True
        while ann:
            xnew= (np.random.rand()*2-1)*h+x[i-1]
            if w(xnew)/w(x[i-1])>=np.random.rand():
                x[i]= xnew
                ann= False
    return x

if executeAllSubExercises:
    #a
    plt.figure(0,figsize=[16,9])
    X = metropolis(np.empty(N), w, h, xStart)
    plt.hist(X, bins=50);
    plt.grid();
    #c
    plt.figure(2,figsize=[16,9])
    X = metropolisAccept(np.empty(N), w, h, xStart)
    plt.hist(X, bins=50);
    plt.grid();

# %% [markdown]
# ### b:

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### a:

# %% [markdown]
# ### b:

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ### a:

# %% [markdown]
# ### b:

# %% [markdown]
# ### c:

# %% [markdown]
# ### d:

# %% [markdown]
# ### e:
